# %%
q=[]
def mem(a):
    q.append(a)
    print(f"список: {q}")
print('Вы вводите элементы в множество "a". Введите "exit" чтобы закончить набор')
while True:
    w=input('Введите число, которое будет в списке: ')  
    if w!='exit':
        do_list(w)
    else:
        break
a=set(q)
q=[]
print('Вы вводите элементы в множество "b". Введите "exit" чтобы закончить набор')
while True:
    w=input('Введите число, которое хотеи бы занести в список: ')  
    if w!='exit':
        do_list(w)
    else:
        break
b=set(q)

c=a&b
print(c)
print(f"В множестве 'a' и 'b' {len(c)} повторяющихся элементов")
# Out:
# Вы вводите элементы в множество "a". Введите "exit" чтобы закончить набор
# Введите число, которое будет в списке: 1
# список: ['1']
# Введите число, которое будет в списке: 2
# список: ['1', '2']
# Введите число, которое будет в списке: 3
# список: ['1', '2', '3']
# Введите число, которое будет в списке: exit
# Вы вводите элементы в множество "b". Введите "exit" чтобы закончить набор
# Введите число, которое хотеи бы занести в список: 4
# список: ['4']
# Введите число, которое хотеи бы занести в список: 3
# список: ['4', '3']
# Введите число, которое хотеи бы занести в список: 5
# список: ['4', '3', '5']
# Введите число, которое хотеи бы занести в список: exit
# {'3'}
# В множестве 'a' и 'b' 1 повторяющихся элементов
